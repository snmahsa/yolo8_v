# %%
# %%capture
# !pip install ultralytics

# %%
# %%capture
# !pip install Ipython

# %%
import matplotlib.pyplot as plt
from IPython.display import Image as imgshow
import os
from ultralytics import YOLO
import numpy as np
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/carsinstreet-288p.mp4" save=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 24.4MB/s]
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# video 1/1 (1/749) /content/carsinstreet-288p.mp4: 384x640 (no detections), 291.0ms
# video 1/1 (2/749) /content/carsinstreet-288p.mp4: 384x640 (no detections), 140.7ms
# video 1/1 (3/749) /content/carsinstreet-288p.mp4: 384x640 (no detections), 149.7ms
# video 1/1 (4/749) /content/carsinstreet-288p.mp4: 384x640 6 cars, 189.6ms
# video 1/1 (5/749) /content/carsinstreet-288p.mp4: 384x640 6 cars, 137.9ms
# video 1/1 (6/749) /content/carsinstreet-288p.mp4: 384x640 7 cars, 137.7ms
# video 1/1 (7/749) /content/carsinstreet-288p.mp4: 384x640 7 cars, 139.7ms
# video 1/1 (8/749) /content/carsinstreet-288p.mp4: 384x640 1 person, 6 cars, 190.8ms
# video 1/1 (9/749) /content/carsinstreet-288p.mp4: 384x640 1 person, 6 cars, 155.4ms
# ...
